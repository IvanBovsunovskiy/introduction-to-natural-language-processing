# %% [markdown]
# # Theory

# %% [markdown]
# #### Векторные представления слов (word embeddings)

# %% [markdown]
# Векторное представление слова (word embedding) — вещественный вектор в пространстве с фиксированной невысокой размерностью.
#
#                                             Пример векторных представлений слов (2D t-SNE)
# <img src='image/2D_tsne.PNG'>
#
# Зачем нужны Word embeddings?
# Сжатые векторные представления слов
# 1. полезны сами по себе, например, для поиска
# синонимов или опечаток в поисковых запросах.
# 2. используются в качестве признаков для решения
# самых различных задач: выявление именованных сущностей, тэгирование частей речи, машинный перевод, кластеризация документов, ранжирование документов, анализ тональности текста.

# %% [markdown]
# ##### word2vec

# %% [markdown]
# Мера семантической близости — мера близости, предназначенная для количественной оценки семантической схожести слов. Такая мера показывает высокие значения для пар слов, находящихся в семантических отношениях (синонимия, ассоциативность и т.д.), и нулевые значения для всех остальных пар.
#
# word2vec - алгоритм для получения векторных представлений слов. Подход основан на важной гипотезе, которую в науке принято называть гипотезой локальности — “слова, которые встречаются в одинаковых окружениях, имеют близкие значения”. Близость в данном случае понимается очень широко, как то, что рядом могут стоять только сочетающиеся слова. Например, для нас привычно словосочетание "заводной будильник". А сказать “заводной апельсин” мы не можем* — эти слова не сочетаются.
#
# ##### Алгоритм word2vec
# Мы будем предсказывать вероятность слова по его окружению (контексту). То есть мы будем учить такие вектора слов, чтобы вероятность, присваиваемая моделью слову была близка к вероятности встретить это слово в этом окружении в реальном тексте.

# %% [markdown]
# <img src='image/w2v_formula.PNG'>

# %% [markdown]
# Здесь W0 — вектор целевого слова, Wc — это некоторый вектор контекста, вычисленный (например, путем усреднения) из векторов окружающих нужное слово других слов. А S — это функция, которая двум векторам сопоставляет одно число. Например, это может быть косинусное расстояние.
#
# Процесс тренировки устроен следующим образом: мы берем последовательно (2k+1) слов, слово в центре является тем словом, которое должно быть предсказано. А окружающие слова являются контекстом длины по k с каждой стороны. Каждому слову в нашей модели сопоставлен уникальный вектор, который мы меняем в процессе обучения нашей модели. В целом, этот подход называется CBOW — continuous bag of words, continuous потому, что мы скармливаем нашей модели последовательно наборы слов из текста, a BoW потому что порядок слов в контексте не важен.
# <img src='image/CBOW_.png'>
# Другой подход skip-gram — прямо противоположный CBOW, то есть “словосочетание с пропуском”. Мы пытаемся из данного нам слова угадать его контекст (точнее вектор контекста). В остальном модель не претерпевает изменений.
# <img src='image/skipgram.png'>
#
# Что стоит отметить: хотя в модель не заложено явно никакой семантики, а только статистические свойства корпусов текстов, оказывается, что натренированная модель word2vec может улавливать некоторые семантические свойства слов. Классический пример:
#
# <img src='image/word_embeddings.PNG'>
#
# Слово "мужчина" относится к слову "женщина" так же, как слово "дядя" к слову "тётя", что для нас совершенно естественно и понятно, но в других моделям добиться такого же соотношения векторов можно только с помощью специальных ухищрений. Здесь же — это происходит естественно из самого корпуса текстов.

# %% [markdown]
# #### Что мы можем попробовать сделать с векторами слов?
#
# Мы можем делать различные синтаксические, семантические NLP задачи с векторами слов, некоторое из них уже встроены.

# %%
import gensim.downloader as api

# %%
api.info()['models'].keys()
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
import gensim.downloader as api

word_vectors = api.load("glove-wiki-gigaword-100")  # загрузим предтренированные вектора слов из gensim-data
# выведим слово наиболее близкое к 'woman', 'king' и далекое от 'man'
result = word_vectors.most_similar(positive=['woman', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))

# %%
result = word_vectors.most_similar(positive=['women', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-c4d47aa25a51> in <module>()
# ----> 1 result = word_vectors.most_similar(positive=['человек', 'король'], negative=['мужчина'])
#       2 print("{}: {:.4f}".format(*result[0]))
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     529                 mean.append(weight * word)
#     530             else:
# --> 531                 mean.append(weight * self.word_vec(word, use_norm=True))
#     532                 if word in self.vocab:
#     533                     all_words.add(self.vocab[word].index)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     450             return result
#     451         else:
# --> 452             raise KeyError("word '%s' not in vocabulary" % word)
#     453
#     454     def get_vector(self, word):
#
# KeyError: "word 'человек' not in vocabulary"

# %%
# выведем лишнее слово
print(word_vectors.doesnt_match("breakfast cereal dinner lunch".split()))

print(word_vectors.doesnt_match("black green summer brown".split()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-180b3373f165> in <module>()
#       1 # выведем лишнее слово
# ----> 2 print(word_vectors.doesnt_match("breakfast cereal dinner lunch".split()))
#       3
#       4 print(word_vectors.doesnt_match("black green summer brown".split()))
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in doesnt_match(self, words)
#     892             logger.warning("vectors for words %s are not present in the model, ignoring these words", ignored_words)
#     893         if not used_words:
# --> 894             raise ValueError("cannot select a word from an empty list")
#     895         vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
#     896         mean = matutils.unitvec(vectors.mean(axis=0)).astype(REAL)
#
# ValueError: cannot select a word from an empty list

# %%
# определим схожесть между словами
similarity = word_vectors.similarity('woman', 'man')
print(similarity)

similarity = word_vectors.similarity('human', 'man')
print(similarity)

similarity = word_vectors.similarity('bee', 'man')
print(similarity)
# Out:
# 0.8323495
# 0.5288512
# 0.21199903

# %%
# найдем top-3 самых близких слов
result = word_vectors.similar_by_word("man", topn=3)
print(result)

result = word_vectors.similar_by_word("cat", topn=3)
print(result)

result = word_vectors.similar_by_word("mouth", topn=3)
print(result)
# Out:
# [('woman', 0.832349419593811), ('boy', 0.7914870977401733), ('one', 0.7788748741149902)]
# [('dog', 0.8798074722290039), ('rabbit', 0.7424426674842834), ('cats', 0.7323004007339478)]
# [('tongue', 0.7366125583648682), ('mouths', 0.687748908996582), ('ear', 0.6811771988868713)]

# %% [markdown]
# ## Simple chat-bot example

# %%
import string
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
import annoy
from gensim.models import Word2Vec, FastText
import pickle
import numpy as np
from tqdm import tqdm_notebook

# %%
# !head -5 gazeta.csv
# Out:
# date,url,edition,topics,authors,title,text,reposts_fb,reposts_vk,reposts_ok,reposts_twi,reposts_lj,reposts_tg,likes,views,comm_count
# 2008-11-21 15:19:14,https://www.gazeta.ru/news/business/2008/11/21/n_1298950.shtml,-,Бизнес,,Госдума сокращает срок действия ставки экспортных пошлин на нефть,"Госдума приняла сегодня в первом чтении и сразу в целом поправки в закон «О таможенном тарифе», сокращающие срок действия ставки экспортных пошлин на нефть с 2-х до 1-го месяца.nnДля установления средних цен на нефть марки Urals и расчета экспортных пошлин правительство России в течение двух месяцев проводит мониторинг на международных рынках нефтяного сырья (средиземноморском и роттердамском), экспортные пошлины на нефть устанавливаются также раз в два месяца.nnСокращение на месяц периода мониторинга (с 15-го числа каждого календарного месяца по 14-е число следующего месяца) и соответственно срока действия ставок экспортных пошлин «позволит более оперативно реагировать на изменения экономической ситуации в стране и сэкономить нефтяникам миллиарды рублей», считают разработчики. Экспортные ставки будут вводиться с 1 числа календарного месяца, следующего за окончанием периода мониторинга.",-,-,-,-,-,-,-,-,-
# 2012-09-27 10:54:51,https://www.gazeta.ru/science/news/2012/09/27/n_2546517.shtml,-,Наука,,Японские физики повторили синтез 113-го элемента,"Японские ученые из физического центра RIKEN заявляют, что им удалось синтезировать атом 113-го элемента таблицы Менделеева - этот элемент был впервые получен в 2003 году российскими и американскими физиками в экспериментах по синтезу 115-го элемента, но это открытие еще не признано Международным союзом теоретической и прикладной химии, сообщаетnРИА «Новости»n.nВ природе не существует элементов с атомными номерами (числом протонов в ядре атома) больше 92, то есть тяжелее урана. Более тяжелые элементы, например, плутоний, могут нарабатываться в атомных реакторах, а элементы тяжелее 100-го (фермия) можно получать только на ускорителях, путем бомбардировки мишени тяжелыми ионами. При слиянии ядер мишени и «снаряда» и возникают ядра нового элемента.nnГруппа ученых под руководством Косуке Морит в статье, опубликованной в Journal of Physical Society of Japan, описывают результаты многолетних экспериментов на линейном ускорителе, расположенном в городе Вако в окрестностях Токио. С 2003 года исследователи пытались получить 113-й элемент, бомбардируя на ускорителе мишень из висмута-209 пучком ионов цинка-70, разогнанных до одной десятой скорости света и висмута.nВ результате им удалось зафиксировать три цепочки распада, соответствующие событию рождения 113-го элемента -23 июля 2004 года, 2 апреля 2005 года и 12 августа 2012 года. Время жизни ядра нового элемента составило от 4,9 до 0,3 миллисекунды.nКак считают японские ученые, их открытие может стать основанием для Международного союза теоретической и прикладной химии признать их открытие. В таком случае японские ученые впервые в истории получат право дать название новому элементу. Однако для признания требуется независимое подтверждение - эксперимент должен быть повторен в другой лаборатории или в перекрестной реакции.n«Это выдающийся результат, но воспроизвести его будет крайне трудно, поскольку регистрируется примерно одно событие в год, а перекрестных реакций не существует», - сказал Андрей Попеко, заместитель директора Лаборатории имени Флерова Объединенного института ядерных исследований в Дубне.",-,-,-,-,-,-,-,-,-
# 2015-12-01 15:28:45,https://www.gazeta.ru/army/news/7957079.shtml,-,Армия,,Times: Россия строит новую авиабазу в Сирии,"Россия готовится расширить свою военную операцию в Сирии и строит там вторую авиабазу, сообщает газетаnThe Timesn.nКак сообщает издание, таким образом, у России появится возможность посылать в регион большее количество боевых самолетов. Автор статьи отмечает, что новая база Аль-Шайрат появится недалеко от сирийского города Хомс.nПо словам местного активиста, там уже размещены российские боевые вертолеты, а также команда, которая прибыла на базу около месяца назад и в настоящее время занимается подготовкой объекта.nnРанееnсообщалось,nчто президент России Владимир Путин согласился с предложением Минобороны перебросить на авиабазу Хмеймим в Сирии новейшие ракетные комплексы С-400. Помимо этого, Россияnнаправитnв Сирию дополнительно 10–12 самолетов для обеспечения прикрытия каждому из 24 российских бомбардировщиков.nС 30 сентября Россия начала проводить военную операцию в Сирии, которая, по официальным данным, направлена на уничтожение боевиков «Исламского государства».n«Исламское государство» — террористическая группировка, деятельность которой запрещена в ряде стран, в том числе в России.",-,-,-,-,-,-,-,-,-
# 2013-04-18 16:42:06,https://www.gazeta.ru/travel/news/2013/04/18/n_2862061.shtml,-,Новости,,Власти Египта гарантируют безопасность российским туристам,"Египет ждет российских туристов и гарантирует иностранным гражданам полную безопасность. Об этом заявил президент Египта Мухаммед Мурси в интервью агентствуnИТАР-ТАССn.nПо его словам, Египет и исторические памятники - в Луксоре, Асуане, на Синае, на Красном море, в Каире - безопасны для посещения туристами.n«Если какие-то инциденты происходят, мы незамедлительно на них реагируем и оказываем помощь оказавшимся в трудном положении туристам, - заявил египетский президент. - Иностранцы могут свободно передвигаться по всей стране, даже в ночное время, например, из Каира в Асуан - и все это безопасно».nnnЕжегодно в Египет приезжает порядка 3 млн россиян, и власти заявляют о желании удвоить эту цифру.n«Мы считаем Россию нашим давним, верным другом и хотим, чтобы она оставалась таковой и сейчас и поддержала египетский народ в этот переходный период от эпохи диктатуры к новой эпохе в истории Египта», - отметил Мухаммед Мурси.",-,-,-,-,-,-,-,-,-

# %%
counter_all = 0
counter_filter = 0
with open("prepared_answers.txt", "r") as f:
    for line in tqdm_notebook(f):
        counter_all +=1
        spls = line.split("\t")
        if len(spls[0].split()) < 2 or len(spls[1].split()) < 3 or len(spls[0].split()) > 15:
            continue
            
        counter_filter +=1
# Out:
# <ipython-input-3-73322b7b2d68>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for line in tqdm_notebook(f):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
assert True

#Small preprocess of the answers

question = None
written = False

with open("prepared_answers.txt", "w") as fout:
    with open("Otvety.txt", "r") as fin:
        for line in tqdm_notebook(fin):
            if line.startswith("---"):
                written = False
                continue
            if not written and question is not None:
                fout.write(question.replace("\t", " ").strip() + "\t" + line.replace("\t", " "))
                written = True
                question = None
                continue
            if not written:
                question = line.strip()
                continue
# Out:
# <ipython-input-6-4e0de9aa106b>:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for line in tqdm_notebook(fin):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4e0de9aa106b> in <module>
#       8 with open("prepared_answers.txt", "w") as fout:
#       9     with open("Otvety.txt", "r") as fin:
# ---> 10         for line in tqdm_notebook(fin):
#      11             if line.startswith("---"):
#      12                 written = False
#
# ~/GB/venv_course/lib/python3.8/site-packages/tqdm/notebook.py in __iter__(self, *args, **kwargs)
#     213     def __iter__(self, *args, **kwargs):
#     214         try:
# --> 215             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     216                 # return super(tqdm...) will not catch exception
#     217                 yield obj
#
# ~/GB/venv_course/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1108             n += 1
#    1109             # check counter first to avoid calls to time()
# -> 1110             if n - last_print_n >= self.miniters:
#    1111                 miniters = self.miniters  # watch monitoring thread changes
#    1112                 delta_t = time() - last_print_t
#
# KeyboardInterrupt:

# %%
def preprocess_txt(line):
    spls = "".join(i for i in line.strip() if i not in exclude).split()
    spls = [morpher.parse(i.lower())[0].normal_form for i in spls]
    spls = [i for i in spls if i not in sw and i != ""]
    return spls

# %%
assert True

# Preprocess for models fitting

sentences = []

morpher = MorphAnalyzer()
sw = set(get_stop_words("ru"))
exclude = set(string.punctuation)
c = 0

with open("Otvety.txt", "r") as fin:
    for line in tqdm_notebook(fin):
        spls = preprocess_txt(line)
        sentences.append(spls)
        c += 1
        if c > 100000:
            break
# Out:
# <ipython-input-8-4964f3fb6446>:13: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for line in tqdm_notebook(fin):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
sentences = [i for i in sentences if len(i) > 2]

# %%
sentences[0]
# Out:
# ['вопрос', 'тдв', 'отдыхать', 'лично', 'советовать', 'завести']

# %%
Word2Vec?

# %%
modelW2V = Word2Vec(sentences=sentences, vector_size=300, window=5, min_count=1)

# %%
modelFT = FastText(sentences=sentences, vector_size=300, min_count=1, window=5, workers=8)

# %%
w2v_index = annoy.AnnoyIndex(300 ,'angular')
ft_index = annoy.AnnoyIndex(300 ,'angular')

index_map = {}
counter = 0

with open("prepared_answers.txt", "r") as f:
    for line in tqdm_notebook(f):
        n_w2v = 0
        n_ft = 0
        spls = line.split("\t")
        index_map[counter] = spls[1]
        question = preprocess_txt(spls[0])
        
        vector_w2v = np.zeros(300)
        vector_ft = np.zeros(300)
        for word in question:
            if word in modelW2V.wv:
                vector_w2v += modelW2V.wv[word]
                n_w2v += 1
            if word in modelFT.wv:
                vector_ft += modelFT.wv[word]
                n_ft += 1
        if n_w2v > 0:
            vector_w2v = vector_w2v / n_w2v
        if n_ft > 0:
            vector_ft = vector_ft / n_ft
        w2v_index.add_item(counter, vector_w2v)
        ft_index.add_item(counter, vector_ft)
            
        counter += 1
        
        if counter > 100000:
            break

w2v_index.build(10)
ft_index.build(10)
# Out:
# <ipython-input-16-64550af31b99>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for line in tqdm_notebook(f):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# True

# %%
def get_response(question, index, model, index_map):
    question = preprocess_txt(question)
    vector = np.zeros(300)
    norm = 0
    for word in question:
        if word in model.wv:
            vector += model.wv[word]
            norm += 1
    if norm > 0:
        vector = vector / norm
    answers = index.get_nns_by_vector(vector, 3, )
    return [index_map[i] for i in answers]

# %%
TEXT = "какой город самы красивый"

# %%
get_response(TEXT, w2v_index, modelW2V, index_map)
# Out:
# ['<br> <br>. \n',
#  'жить в родных краях, кататься по всему миру. \n',
#  'Конечно. Это город в Дагестане на узком проходе между Каспийским морем и предгорьями Кавказа. Дербент — самый южный город Российской Федерации. <br>Дербент — иногда считают одним из древнейших «живущих» городов мира, старейшим городом Российской Федерации. Первые поселения возникли здесь в эпоху ранней бронзы — в конце 4 тысячелетия до н. э. . Первое упоминание Каспийских ворот — наиболее древнего названия Дербента — относится к VI в. до н. э. , его приводит известный древнегреческий географ Гекатей Милетский.. \n']

# %%
get_response(TEXT, ft_index, modelFT, index_map)
# Out:
# ['г Санкт-Петербург.. \n',
#  'Шеньчжень <br> <br> <br> <br>Город расположен в 120 км от Гуанчжоу. Одна из первых Специальных Экономических Зон Китая. Шэньчжэнь возник на месте бывшей рыбацкой деревушки на границе с Гонконгом. За 20 лет превратился в современный город с населением в 3 млн. человек. Въезд китайцев в Шэньчжэнь ограничен. В городе самый высокий уровень жизни в Китае. В городе и пригородах находятся предприятия Гонконга, Тайваня, Сингапура, Японии, Южной Кореи, США, стран Западной Европы. Свыше 80% производимой продукции экспортируется. <br> <br>http://travel.gala.net/ref/cn/_enchzhen/ <br>Многие иностранные посетители говорят, что Шэньчжэнь - это то, что было бы с Китаем, если бы не коммунизм. Шэнчжэнь является горячей туристической точкой в Китае. Здесь возможно прекрасно провести отпуск: пляжи, тематические парки, отличные отели. Но настоящая жизнь в Шеньчжене начинается ночью. Культурной жизнью города заправляют частные компании, чем объясняется необыкновенное разнообразие: танцевальные залы, дискотеки, караоке, чайные домики, бары. Самое последнее развлечение Хард-рок кафе. <br>Шеньчжэнь славится своими песчаными пляжами - прозрачная вода; сети, защищающие пляж от акул; верховая езда по пляжу; прокат водных лыж и другого снаряжения для отдыха на воде - все это райский уголок между морем и горами. Также в Шеньчжене вы просто обязаны посетить основные достопримечательности, такие как: этнографические ландшафтные парки, самым известным из которых является <br> <br> <br> <br>Парк «Окно в мир» : он разделен на 9 основных частей: Мир, Азия, Океания, Европа, Америка, Центр современной науки и технологии, Парк скульптур, Международная улица, <br> <br> <br> <br>Парк «Китай в миниатюре» , океанариум, авианосец «Минск» , а также <br> <br> <br> <br> “Этнографическую деревню”, развлекательный центр Сянмиху, где расположен большой аквапарк с аттракционами и шоу. <br> <br> <br>Парк «Веселый мир» <br> <br>Большинство посетителей проводит свободное время в магазинах и ресторанах в городе Шэньчжэнь на улицах Рэньминьнаньлу (Renmin Nanlu) и Цзяньшэлу (Jiangshe Lu). <br> <br>http://www.asia-planet.com.ua/country/china/Shenzhen/13/ <br>http://www.hbstravel.ru/country/5/city/25/photo/. \n',
#  '<p>Красивая королевская змея (Lampropeltis calligaster)\xa0— неядовитая змея семейства ужеобразных (Colubridae). Имеет 3 подвида. </p> <p>Общая длина достигает 0,75—1\xa0м. Голова сжатая с боков, немного вытянута. Глаза большие. Туловище стройное и массивное. Окраска варьирует от палевого до коричневого с тёмно-коричневыми или красными прямоугольными поперечными пятнами. Молодые особи имеют более контрастные цвета с тёмными пятнами на светлом, розовом фоне. Брюхо желтоватое с чёрными прямоугольными поперечными пятнами. Встречаются альбиносы, которые окрашены в розовые и красные тона, без примеси чёрного и коричневого. </p> <p>Любит засушливые биотопы: прерии, редколесья, кустарниковые пустоши, лесные поляны. Значительную часть жизни проводит под землёй, где роет длинные ходы. На поверхности эту змею можно встретить нечасто. Обычно селится неподалёку от постоянных водоёмов. Питается грызунами, лягушками, птицами и другими змеями. </p> <p>Это яйцекладущая змея. Самка откладывает до 12 яиц. </p> <p>Обитает в центральных и юго-восточных районах США от Техаса до Северной Каролины и Флориды. </p> <h2>Примечания</h2> <h2>Литература</h2> <ul> <li>Collins J.T. &amp; Collins S.L. Lampropeltis calligaster // A pocket guide to Kansas snakes.\xa0— 4.\xa0— Wichita: Great Plains Nature Center, 2012.\xa0— P.\xa08–9.\xa0— 69\xa0p.</li> <li>Словник-довідник із зоології.\xa0— К., 2002.</li> <li>Enge, Kevin M. 2009. Venomous and non-venomous snakes of Florida. Publication of the Florida Fish &amp; Wildlife Conservation Commission. 16 pp.</li> <li>Thissen, R. &amp; Hansen, H. 2001. Königsnattern\xa0— Lampropeltis. Natur und Tier Verlag (Münster), 172 pp.</li></ul>. \n']

# %% [markdown]
# # HW
# Урок 3. Embedding word2vec fasttext
# Задача поиск похожих по эмбеддингам
# Скачиваем датасет
#
# !wget https://github.com/ods-ai-ml4sg/proj_news_viz/releases/download/data/gazeta.csv.gz
#
# # пример работы с ним
# from corus import load_ods_gazeta
# path = 'gazeta.csv.gz'
# records = load_ods_gazeta(path)
# next(records)
#
# что надо сделать
# 1.   на основе word2vec/fasttext реализовать метод поиска ближайших статей (на вход метода должен приходить запрос (какой-то вопрос) и количество вариантов вывода к примеру 5-ть, ваш метод должен возвращать 5-ть ближайших статей к этому запросу)
# 2.   Проверить насколько хорошо работают подходы

# %% [markdown]
# ## Imports

# %%
# !pip install pymorphy2 -q
# !pip install stop_words -q
# !pip install annoy -q
# Out:
#      |████████████████████████████████| 55 kB 4.1 MB/s
#      |████████████████████████████████| 8.2 MB 48.3 MB/s
#   Building wheel for stop-words (setup.py) ... done
#      |████████████████████████████████| 646 kB 16.9 MB/s
#   Building wheel for annoy (setup.py) ... done

# %%
import string


import annoy
import gensim
from gensim.models import Word2Vec, FastText
import pickle
import numpy as np
import tqdm
from tqdm import tqdm_notebook

# %%
import pandas as pd
import numpy as np
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words

#from stop_words import get_stop_words
#import annoy
from gensim.models import Word2Vec, FastText
#import pickle
from tqdm import tqdm_notebook

# %% [markdown]
# ## Data downloading

# %%
from os.path import exists

if not(exists('gazeta.csv.gz')):
  # !wget https://github.com/ods-ai-ml4sg/proj_news_viz/releases/download/data/gazeta.csv.gz -q
if not(exists('gazeta.csv')):
  !7z x gazeta.csv.gz
  if exists('gazeta.csv.gz'):
    # !rm 'gazeta.csv.gz'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 477029050 bytes (455 MiB)
#
# Extracting archive: gazeta.csv.gz
# --
# Path = gazeta.csv.gz
# Type = gzip
# Headers Size = 21
#
# Everything is Ok
#
# Size:       1956320939
# Compressed: 477029050

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Papers processing

# %%
def preprocess_txt(line):
    spls = line.split(',')[3:6]
    try:
      spls.remove('')
    except ValueError:
      pass
    finally:
      spls = ' '.join(spls)
    spls = "".join(i for i in line.strip() if i not in exclude).split()
    spls = [morpher.parse(i.lower())[0].normal_form for i in spls]
    spls = [i for i in spls if i not in sw and i != ""]
    return spls

# %%
def text_preprocessing(text):
  try:
    updated_text = text.lower()
  except :
    updated_text = text
  return updated_text

# %%
# memory consumption
"""papers = pd.read_csv('gazeta.csv')
print(papers.columns)

drop_columns_list = ['url','edition', 'text', 'reposts_fb', 'reposts_vk', 
                     'reposts_ok', 'reposts_twi', 'reposts_lj',
                     'reposts_tg', 'likes', 'views', 'comm_count']
papers.drop(columns=drop_columns_list, inplace=True)

# older news in the end of dataframe
papers.sort_values('date', ascending=False, inplace=True)

for column in ['topics', 'authors', 'title']:
  papers[column] = papers[column].apply(text_preprocessing)"""
# Out:
# "papers = pd.read_csv('gazeta.csv')\nprint(papers.columns)\n\ndrop_columns_list = ['url','edition', 'text', 'reposts_fb', 'reposts_vk', \n                     'reposts_ok', 'reposts_twi', 'reposts_lj',\n                     'reposts_tg', 'likes', 'views', 'comm_count']\npapers.drop(columns=drop_columns_list, inplace=True)\n\n# older news in the end of dataframe\npapers.sort_values('date', ascending=False, inplace=True)\n\nfor column in ['topics', 'authors', 'title']:\n  papers[column] = papers[column].apply(text_preprocessing)"

# %%
sentences = []
c = 0
morpher = MorphAnalyzer()
sw = set(get_stop_words("ru"))
exclude = set(string.punctuation)
file_length = 20000

with open("gazeta.csv", "r") as fin:
    for line in tqdm_notebook(fin):
      spls = preprocess_txt(line)
      sentences.append(spls)
      c += 1
      if c > file_length:
          break
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Model preparation/training

# %% [markdown]
# ### Russian corpus
# 'день_NOUN' - words in vocab - problem

# %%
if not(exists('180.zip')):
  # !wget http://vectors.nlpl.eu/repository/20/180.zip -q

# %%
import zipfile
model_file = '180.zip'
with zipfile.ZipFile(model_file, 'r') as archive:
   stream = archive.open('model.bin')
   model = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True)

# %%
words = ['день_NOUN', 'ночь_NOUN', 'человек_NOUN', 'семантика_NOUN', 'студент_NOUN', 'понедельник_NOUN']
for word in words:
  if word in model:
    print(word)
    similarity = model.similarity('дата_NOUN', word)
  else:
    similarity = 0
  print(similarity)
# Out:
# день_NOUN
# 0.24648403
# ночь_NOUN
# -0.058418483
# человек_NOUN
# -0.116438575
# семантика_NOUN
# 0.13351995
# студент_NOUN
# -0.0667172
# понедельник_NOUN
# 0.20837255

# %%
'человек_NOUN' in  model.vocab
# Out:
# True

# %% [markdown]
# ### Word2Vec

# %%
modelW2V = Word2Vec(min_count=2, sentences=sentences, window=5)
modelW2V.save("word2vec.model")

# %% [markdown]
# ### FastText

# %%
modelFT = FastText(sentences=sentences, min_count=2, window=5)
modelFT.save("fasttext.model")

# %% [markdown]
# ## Word2Vec and FastText recommendations

# %%
papers_number = 5
input_request = 'новости экономика'

# %%
counter = 0
lines2request_similarity_w2v = pd.DataFrame(columns=['line', 'similarity'])
lines2request_similarity_ft = pd.DataFrame(columns=['line', 'similarity'])

with open("gazeta.csv", "r") as f:
  for line in tqdm.notebook.tqdm(f):
    if counter > 0:
      corrected_line = preprocess_txt(line)
      counter += 1
      line2request_similarity_w2v = 0
      line2request_similarity_ft = 0
      for word_news in corrected_line:
        for word_request in preprocess_txt(input_request):
          if (word_request in modelW2V)and(word_news in modelW2V):
            line2request_similarity_w2v += modelW2V.wv.similarity(word_news, word_request)
          if (word_request in modelFT)and(word_news in modelFT):
            line2request_similarity_ft += modelFT.wv.similarity(word_news, word_request)
      lines2request_similarity_w2v = lines2request_similarity_w2v.append({'line':line.split(',')[0],
                                                                          'similarity':line2request_similarity_w2v},
                                                                         ignore_index=True)
      lines2request_similarity_ft = lines2request_similarity_ft.append({'line':line.split(',')[0],
                                                                        'similarity':line2request_similarity_ft},
                                                                       ignore_index=True)
      if not(counter%(2*papers_number)):
        lines2request_similarity_w2v = lines2request_similarity_w2v.sort_values(by=['similarity'],
                                                                                ignore_index=True,
                                                                                na_position='first')[-5:]
        lines2request_similarity_ft = lines2request_similarity_ft.sort_values(by=['similarity'], 
                                                                              ignore_index=True,
                                                                              na_position='first')[-5:] 
      if counter > 2*file_length:
        
        break
    else:
      counter += 1

lines2request_similarity_w2v = lines2request_similarity_w2v.sort_values(by=['similarity'],
                                                                        ignore_index=True,
                                                                        na_position='first')[-5:]
lines2request_similarity_ft = lines2request_similarity_ft.sort_values(by=['similarity'], 
                                                                      ignore_index=True,
                                                                      na_position='first')[-5:]
print(f'Word2Vec recommendations (file line with score):\n{lines2request_similarity_w2v}')
print(f'FastText recommendations (file line with score):\n{lines2request_similarity_ft}')
# Out:
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   app.launch_new_instance()
# Word2Vec recommendations (file line with score):
#                   line  similarity
# 1  2018-03-27 06:59:56  701.822227
# 2  2018-02-11 15:48:05  706.990806
# 3  2014-07-17 19:21:42  714.852607
# 4  2013-03-13 19:31:00  716.593466
# 5  2018-09-14 08:36:27  771.362024
# FastText recommendations (file line with score):
#                   line  similarity
# 1  2014-07-17 19:21:42  719.348175
# 2  2018-03-27 06:59:56  855.942173
# 3  2018-12-31 08:22:24  887.223314
# 4  2018-02-11 15:48:05  895.066923
# 5  2018-03-26 08:43:41  918.171655

# %%
with open("gazeta.csv", "r") as f:
  for line in tqdm_notebook(f):
    if line.split(',')[0] in list(lines2request_similarity_w2v['line']):
      print(f'Word2Vec recommendation:\n{line}\n')
    if line.split(',')[0] in list(lines2request_similarity_ft['line']):
      print(f'FastText recommendation:\n{line}\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]
# Word2Vec recommendation:
# 2013-03-13 19:31:00,https://www.gazeta.ru/social/2013/03/12/5054161.shtml,-,Общество,"Анастасия Берсенева,Максим Солопов,Дарья Загвоздина",Онлайн-репортаж из Ватикана: выборы папы римского,"Новый глава Римско-католической церкви избран с третьего раза: вечером в среду из трубы Сикстинской капеллы, в которой собрался конклав из 115 кардиналов Римско-католической церкви, показался белый дым. 266-м понтификом стал кардинал из Аргентины Хорхе Марио Бергольо.nnВпервые за всю историю Римско-католической церкви престол Святого Петра занял выходец из Латинской Америки, принадлежащий к ордену иезуитов. Папа римский Франциск I обратился к верующим, собравшимся на площади, с небольшой речью. Онвозблагодарил Бога за то, что католики всего мира получили нового понтифика, выразил благодарность кардиналам, избравшим его, а также собравшимся на площади перед собором святого Петра в Риме. конце своего выступления Франциск попросил собравшихся попросить у Бога, чтобы Он вдохновил нового понтифика на служение.nФранциск I закончил свое короткое выступление словами: «А теперь я должен вас покинуть. Спокойной ночи!»nnКардиналы пытались избрать папу с чистой репутацией», - пояснил «Газете.Ru» научный сотрудник Центра изучения Восточной Европы Бременского университета Николай Митрохин. По его словам, подтвердились прогнозы, что конклав изберет папу из страны третьего мира. Но при этом имя Берголье не звучало ни в одном прогнозе. Фаворитом считались африканский кардинал из Ганы и итальянец. Выбор имени Франциск означает, что церковь будет ориентирована на помощь неимущим, говорит Митрохин «Церковь выбрала социально-ориентированного папу», - пояснил он.nnПапа благословляет собравшихся на площади. «Но перед этим благословите меня, - просит он. - В тишине попросите Бога благословить меня».nn«Первое, давайте помолимся за нашего почетного епископа Бенедикта XVI», - сказал новый папа римский Франциск I.nnСообщается, что это первый папа-иезуит. Бергольо вступил в орден иезуитов в 1958 году. В 1992 году он стал вспомогательным епископом в Буэнос-Айресе, что для иезуита в немиссионерских странах большая редкость.nnНовый папа вел скромный образ жизни: жил в маленькой квартире, отказался от лимузина с шофером, сам себе готовил пищу.nnПапой римский стал 76-летний аргентинский кардинал Хорхе Марио Бергольо. Он выбрал себе новое имя - Франциск. После смерти папы римского Иоанна Павла II, Бергольо был вызван в Ватикан для участия в папском Конклаве 2005 года. Тогда Бергольо рассматривался как вероятный папабиль, но не был выбран.nnВ первых рядах толпы перед собором стоит мэр Рима Джованни Алеманно.nnШторы раскрылись, и на балкон вышел кардинал с двумя помощниками.nnЧисло собравшегося народа слишком велико для площади Святого Петра. Народ стоит очень плотно. Примерно 100 тысяч человек сейчас собралось на площади, сообщает Catholic News Service.nnВ комнате, в которую ведет балкон, зажегся свет. Толпа снова радостно закричала.nnКамера Vatican TV показала балкон на соборе Святого Петра, на котором должен в ближайшее время появиться кардинал, обнародующий имя нового папы, а затем сам новоизбранный понтифик. Окна балкона прикрывают красные шторы.nnПредводители швейцарских гвардейцев и карабинеров салютовали друг другу. Вся площадь скандирует «Viva il Papa!»nnМузыканты и полицейские выстроились перед собором. Сначала был сыгран итальянский национальный гимн - вся площадь подпевала. Затем был сыгран гимн Ватикана.nnЕще один оркестр вышел на площадь перед собором. Музыканты - в черных накидках с красной подкладкой и кокордами на шляпах. За ними выходит ватиканская жандармерия. «Прибыли швейцарские гвардейцы, - сообщает Catholic News Service. - Итальянский военный оркестр, карабинеры».nnНа площадь Святого Петра вышел оркестр. Облаченные в синие одеяния с желтой подкладкой музыканты направились к собору. За ними следуют вооруженные гвардейцы в серых накидках с пиками в руках и в железных шлемах с гребешками.nnОжидание может затянуться, если папа выбран среди претендентов, кото ...
#
#
# Word2Vec recommendation:
# 2014-07-17 19:21:42,https://www.gazeta.ru/social/2014/07/17/6117889.shtml,-,Общество,Отдел «Общество»,На границе Украины и России сбит Boeing 777,"На границе России и Украины был сбит Boeing 777. На борту самолета находились 283 пассажира и 15 членов экипажа — все они погибли. Рейс, который принадлежит «Малайзийским авиалиниям», следовал по маршруту Амстердам — Куала-Лумпур. «Газета.Ru» ведет онлайн-трансляцию о последних событиях вокруг крушения самолета.nnПрезидент Украины Петр Порошенко провел телефонный разговор с немецким канцлером Ангелой Меркель, в ходе которого стороны обсудили крушение авиалайнера Boeing Malaysia Airlines и ситуацию на востоке Украины.nnКанцлер Германии Ангела Меркель призвала Францию прекратить экспорт вертолетоносцев типа «Мистраль» в Россию, сообщает EUobserver. Меркель добавила, что Германия приостанавливает строительство стрелкового центра в России. Соответствующее заявление прозвучало после крушения малайзийского Boeing 777 на Украине.nnСовбез ООН призвал провести независимое международное расследование крушения малайзийского Boeing в Донецкой области Украины. Как передает CNN, об этом говорится в заявлении, принятом 18 июля. Как следует из заявления, члены Совета Безопасности ООН призывают к полному, тщательному и независимому международному расследованию этого инцидента в соответствии с инструкциями Международной организации гражданской авиации (ИКАО).nnНАТО не участвует в расследовании обстоятельств крушения малайзийского Boeing 777 на Украине. Об этом сообщает РИА «Новости» со ссылкой на источник в НАТО. При этом накануне генсек НАТО Андерс Фог Расмуссен призвал к тому, чтобы полноценное международное расследование было запущено немедленно.nnГруппа из 30 наблюдателей ОБСЕ прибыла на Украину и вскоре прилетела на вертолете в Донецкую область для обследования места крушения малайзийского Boeing 777, передает Reuters.nnЧетыре пассажира еще не идентифицированы, сообщает авиакомпания «Малайзийские авиалинии». По последним данным, на борту было 189 голландцев, 44 малайзийца, 27 австралийцев, 12 индонезийцев, 9 граждан Великобритании, 4 бельгийца, 4 гражданина Германии, 3 филиппинца, 1 канадец и 1 гражданин Новой Зеландии.nnУкраинские диспетчеры потребовали от малайзийского Boeing 777 лететь ниже плана полета. Об этом сообщает Reuters со ссылкой на источник Malaysia Airlines. Отмечается, что план полета предусматривал высоту 35 тыс. футов (более 10,66 км), но пилоты снизились по требованию диспетчеров до 33 тыс. футов (более 10,05 км).nnВ крушении самолета погибли два болельщика английского футбольного клуба «Ньюкасл». «Оба болельщика преданно поддерживали команду и были известны как тысячам болельщиков, так и сотрудникам клуба. От имени всего клуба «Ньюкасл» мы выражаем глубокие соболезнования семьям и друзьям погибших», — цитирует «Интерфакс» заявление футбольного клуба. Погибшие — Джон Алдэр и Лиам Суини — направлялись на товарищескую игру команды в Новой Зеландии. Управляющий директор клуба Ли Чарнли заявил, что во время первой игры «Ньюкасла» в премьер-лиге против «Манчестер Сити» 17 августа пройдут специальные мероприятия. Также было принято решение, что в двух товарищеских матчах игроки «Ньюкасла» выйдут на поле в траурных повязках.nnПремьер-министр Малайзии Наджиб Разак говорит по телефону с генеральным секретарем ООН Пан Ги Муном.nI spoke to UN Sec-Gen Ban Ki Moon aboutn#MH17nright after iftar.npic.twitter.com/GJgTJ8tY8TnnГлава МИД России Сергей Лавров заявил, что Россия не будет забирать себе «черные ящики» Boeing 777.nСергей Лавров: Мы не собираемся забирать ""чёрные ящики"" BoeingnnПродолжается поиск тел погибших в крушении. Они разбросаны на территории в несколько километров.nRTn@STForeignDeskn:n#MalaysiaAirlinesn#MH17n: Ukraine rescuers recover 181 bodies at crash sitennhttp://t.co/oauXWoO8bunpic.twitter.com/Hb16dOFPA3nnЭксперты ДНР могли ошибиться с «черными ящиками». Премьер самопровозглашенной Донецкой народной республики Александр Бородай заявил, что он пока не может подтвердить ф ...
#
#
# FastText recommendation:
# 2014-07-17 19:21:42,https://www.gazeta.ru/social/2014/07/17/6117889.shtml,-,Общество,Отдел «Общество»,На границе Украины и России сбит Boeing 777,"На границе России и Украины был сбит Boeing 777. На борту самолета находились 283 пассажира и 15 членов экипажа — все они погибли. Рейс, который принадлежит «Малайзийским авиалиниям», следовал по маршруту Амстердам — Куала-Лумпур. «Газета.Ru» ведет онлайн-трансляцию о последних событиях вокруг крушения самолета.nnПрезидент Украины Петр Порошенко провел телефонный разговор с немецким канцлером Ангелой Меркель, в ходе которого стороны обсудили крушение авиалайнера Boeing Malaysia Airlines и ситуацию на востоке Украины.nnКанцлер Германии Ангела Меркель призвала Францию прекратить экспорт вертолетоносцев типа «Мистраль» в Россию, сообщает EUobserver. Меркель добавила, что Германия приостанавливает строительство стрелкового центра в России. Соответствующее заявление прозвучало после крушения малайзийского Boeing 777 на Украине.nnСовбез ООН призвал провести независимое международное расследование крушения малайзийского Boeing в Донецкой области Украины. Как передает CNN, об этом говорится в заявлении, принятом 18 июля. Как следует из заявления, члены Совета Безопасности ООН призывают к полному, тщательному и независимому международному расследованию этого инцидента в соответствии с инструкциями Международной организации гражданской авиации (ИКАО).nnНАТО не участвует в расследовании обстоятельств крушения малайзийского Boeing 777 на Украине. Об этом сообщает РИА «Новости» со ссылкой на источник в НАТО. При этом накануне генсек НАТО Андерс Фог Расмуссен призвал к тому, чтобы полноценное международное расследование было запущено немедленно.nnГруппа из 30 наблюдателей ОБСЕ прибыла на Украину и вскоре прилетела на вертолете в Донецкую область для обследования места крушения малайзийского Boeing 777, передает Reuters.nnЧетыре пассажира еще не идентифицированы, сообщает авиакомпания «Малайзийские авиалинии». По последним данным, на борту было 189 голландцев, 44 малайзийца, 27 австралийцев, 12 индонезийцев, 9 граждан Великобритании, 4 бельгийца, 4 гражданина Германии, 3 филиппинца, 1 канадец и 1 гражданин Новой Зеландии.nnУкраинские диспетчеры потребовали от малайзийского Boeing 777 лететь ниже плана полета. Об этом сообщает Reuters со ссылкой на источник Malaysia Airlines. Отмечается, что план полета предусматривал высоту 35 тыс. футов (более 10,66 км), но пилоты снизились по требованию диспетчеров до 33 тыс. футов (более 10,05 км).nnВ крушении самолета погибли два болельщика английского футбольного клуба «Ньюкасл». «Оба болельщика преданно поддерживали команду и были известны как тысячам болельщиков, так и сотрудникам клуба. От имени всего клуба «Ньюкасл» мы выражаем глубокие соболезнования семьям и друзьям погибших», — цитирует «Интерфакс» заявление футбольного клуба. Погибшие — Джон Алдэр и Лиам Суини — направлялись на товарищескую игру команды в Новой Зеландии. Управляющий директор клуба Ли Чарнли заявил, что во время первой игры «Ньюкасла» в премьер-лиге против «Манчестер Сити» 17 августа пройдут специальные мероприятия. Также было принято решение, что в двух товарищеских матчах игроки «Ньюкасла» выйдут на поле в траурных повязках.nnПремьер-министр Малайзии Наджиб Разак говорит по телефону с генеральным секретарем ООН Пан Ги Муном.nI spoke to UN Sec-Gen Ban Ki Moon aboutn#MH17nright after iftar.npic.twitter.com/GJgTJ8tY8TnnГлава МИД России Сергей Лавров заявил, что Россия не будет забирать себе «черные ящики» Boeing 777.nСергей Лавров: Мы не собираемся забирать ""чёрные ящики"" BoeingnnПродолжается поиск тел погибших в крушении. Они разбросаны на территории в несколько километров.nRTn@STForeignDeskn:n#MalaysiaAirlinesn#MH17n: Ukraine rescuers recover 181 bodies at crash sitennhttp://t.co/oauXWoO8bunpic.twitter.com/Hb16dOFPA3nnЭксперты ДНР могли ошибиться с «черными ящиками». Премьер самопровозглашенной Донецкой народной республики Александр Бородай заявил, что он пока не может подтвердить ф ...
#
#
# FastText recommendation:
# 2018-12-31 08:22:24,https://www.gazeta.ru/social/2018/12/31/12115135.shtml,-,Общество,Отдел «Общество»,Взрыв в Магнитогорске: хроника первых дней трагедии,"Число погибших после обрушения подъезда в многоэтажном жилом доме в Магнитогорске в ночь на 31 декабря выросло до девяти человек. СК России завел уголовное дело по статье «Причинение смерти по неосторожности»: причиной происшествия стал взрыв бытового газа. Президент России Владимир Путин прибыл в Магнитогорск, провел совещание в оперативном штабе, навестил 13-летнего подростка, пострадавшего при обрушении. Спасатели продолжают разбирать завалы. «Газета.Ru» следила за развитием событий в режиме онлайн.nnВторое января объявлено днем траура в Челябинской области по погибшим при взрыве газа в жилом доме в Магнитогорске, соответствующее распоряжение сделал глава региона Борис Дубровский.nТраур начался в полночь на среду в регионе (22.00 вторника мск). По всему региону будут приспущены государственные флаги РФ и Челябинской области. Учреждениям, организациям и телерадиокомпаниям рекомендовано отменить развлекательные мероприятия и передачи в день траура.nnn«Газета.Ru» завершает онлайн и приносит соболезнования всем близких погибших и пострадавших.nnВечером 1 января в Магнитогорске загорелась маршрутка. Очевидцы сообщили, что услышали хлопок, после чего автомобиль охватило пламя. В пресс-службе ГУ МВД региона заявили, что, по предварительным данным, причина хлопка — неисправность газового оборудования. На месте происшествия работает следственно-оперативная группа. Обстоятельства выясняются. Погибли три человека, сообщил РИА «Новости» представитель экстренных служб.nnВ школе на первом этаже практически каждый кабинет определен под конкретную категорию вещей, и вещей, и продуктов в настоящее время хватает, уточнил Сычков. По его словам, в штабе работает большое число волонтеров - они встречают приходящих за помощью, составляют списки того, что каждому требуется.nnОколо 100 человек обратились 31 декабря и 1 января в штаб оказания помощи пострадавшим при взрыве бытового газа в городе Магнитогорск Челябинской области, сообщил РИА Новости член общественной молодежной палаты при магнитогорском горсобрании Вадим Сычков. «В школе №14, где организован штаб помощи населению, второй день продолжается работа волонтеров, психологов, медиков, полиции. Всем обратившимся оказывается всесторонняя помощь. Пострадавшие приходят за продуктами, одеждой, бытовой химией, зарядниками для телефонов, детскими вещами, игрушками. За два дня обратилось примерно 100 человек», — сказал собеседник агентства.nnВсего же в пункте временного размещения работают 150 волонтеров, постоянно находятся на месте 35 человек. Кроме того, в столовой школы организованно горячее питание, как для специалистов, работающих на месте происшествия, так и для пострадавших и их близких. С родственниками также работают священнослужители, сообщили в ГУ МЧС региона.nnСвежие цифры от ГУ МЧС по Челябинской области. С момента начала поисково-спасательной операции из-под завалов извлекли 15 человек, из них 9 человек погибли (детей нет), 6 — спасены (в том числе 2 ребенка). Все пострадавшие были доставлены в медицинские учреждения. Проводится работа по установлению местонахождения еще 32 человек, сообщает 74.ru.nnСпасенного младенца доставят в московскую клинику Рошаля. Об этом сообщила уполномоченный по правам ребенка в РФ Анна Кузнецова. «На связи с докторами. Надежда есть. Это чудо, конечно!» — написала она в инстаграме.nnПродолжают поступать соболезнования в связи с трагедией в Магнитогорске. В частности, их принес президент Белоруссии Александр Лукашенко. Он отметил, что в республике с глубокой печалью восприняли известие о случившейся в трагедии. «Огромная боль от невосполнимых утрат наполнила сердца всех белорусов. Мы скорбим вместе с братским российским народом и разделяем тяжесть постигшей его беды», — говорится в соболезновании.nnПрезидент России Владимир Путин по телефону поблагодарил спасателей, которые работают на месте обрушения  ...
#
#
# Word2Vec recommendation:
# 2018-09-14 08:36:27,https://www.gazeta.ru/social/2018/09/14/11966809.shtml,-,Общество,"Яков Лысенко,Анна Лозинская",Наводнение в США: сотни тысяч американцев покинули свои дома,"На Америку обрушился тропический ураган «Флоренс». В Северной и Южной Каролине, а также Виргинии был объявлен режим чрезвычайной ситуации. Более миллиона человек покинули свои дома. Ожидается, что ураган принесет в Штаты не менее 70 млрд тонн осадков. Большая их часть выпадет на территории Северной Каролины. «Газета.Ru» следила за развитием событий в режиме онлайн.nnНа этом «Газета.Ru» завершает свою онлайн-трансляцию. Спасибо, что вместе с нами следили за этим тяжелым для США днем. Мы надеемся, что ураган «Флоренс» ослабит свою хватку, и местные жители смогут вернуться в свои дома. Будем держать вас в курсе всех новостей!nКоротко о том, что произошло в США за сегодня:nn— Ураган «Флоренс» достиг побережья Северной Каролины. За несколько дней сила циклона ослабла с четвертой до первой категории. Скорость движения урагана составляла 9,5 км/час, ветра — 150 км/час.nnn— В Северной и Южной Каролине, а также Виргинии был объявлен режим чрезвычайной ситуации. Предупреждения об эвакуации были распространены для 1,7 млн американцев. Более миллиона человек были эвакуированы. Около 20 тыс. укрываются во временных убежищах. На юго-востоке США отменили почти полторы тысячи авиарейсов.nnn— Синоптики прогнозируют, что ураган принесет в Штаты не менее 70 млрд тонн осадков. Большая их часть выпадет на территории Северной Каролины.nnn— Большая часть города Нью-Берн, расположенного в Северной Каролине, в результате урагана находится под трехметровым слоем воды.nnn— Ураган оставил без электричества более 600 тыс. домов. «Флоренс» повлек за собой масштабные наводнения, а также повысил угрозу возникновения оползней в горах и предгорьях.nnБольшая часть города Райтсвилл Бич в Северной Каролине находится под водой. Об этом сообщает корреспондент Fox News Рик Левенталь. И это неудивительно — прибрежный город расположен на высоте всего два метра над уровнем океана. Именно на него утром в пятницу пришелся удар урагана Флоренс.nBig stretches of Wrightsville Beach NC now underwatern#HurricaneFlorencenpic.twitter.com/vd0fwL0DEAnnТем временем, уже более 600 тыс. домой в Северной и Южной Каролине остались без электричества из-за урагана Флоренс.nnСамая смелая собака по кличке Мэгги в схватке с ураганом Флоренс. Просто взгляните на это.nThe bravest dog facingn#FlorenceHurricane2018nLove little Maggie's spirit.n@KariHallWeathernpic.twitter.com/j2iP0bZFfgnnУраган Флоренс внес свои коррективы в планы 56-летних Марши Брэдбери и Джонатана Гилленвотер. Жители Западной Виргиния 16 сентября собирались устроить свадьбу на живописном берегу Северной Каролины в Сальво.nnnОни планировали торжество с марта, однако в понедельник поняли, что все сорвано.n«Я прорыдала весь понедельник — зная, что это не поможет, я продолжала плакать», — призналась Брэдбери изданию People.nnПозже мэр города Харрикейн Скотт Эдвардс предложил паре провести церемонию в мэрии бесплатно. Узнав об этом предложении, местные жители начали предлагать Маршу и Джонатану помощь в организации свадьбы — цветы, фотографа и известного ди-джея.nnn«Сначала все это меня очень расстроило, но теперь у нас есть ключ ко всему городу с вечера пятницы и до воскресенья», — рассказала Брэдбери.nnК операции в Северной Каролине подключились поисково-спасательные собаки — вместе с правохранителями они ищут людей, которые спрятались от шторма, и оказывают им помощь.nSAY HI TO MORTY! He's with the Disaster Response Canine Unit.n@DWilsonABC11ncaught up with him in Wilmington and Wrightsville Beach. He's ready to help inn#Florencen. He's a good boy!npic.twitter.com/crC69fpAfqnnНапомним, что ровно год назад на Антильские острова и Флориду обрушился ураган «Ирма», который был признан самым продолжительным ураганом 5 категории за всю историю наблюдений. Скорость ветра достигла 297 км/ч — это сделало «Ирму» сильнейшим тропическим циклоном с 2005 года.nnnИз ...
#
#
# FastText recommendation:
# 2018-03-26 08:43:41,https://www.gazeta.ru/social/2018/03/26/11695717.shtml,-,Общество,Отдел «Общество»,Число погибших при пожаре в кемеровском ТЦ «Зимняя вишня» составляет 64,"В Кузбассе объявлен трехдневный траур по погибшим при пожаре в ТЦ «Зимняя вишня». В знак солидарности с жителями региона отменили развлекательные мероприятия власти Ингушетии и Рязанской области. На месте трагедии по-прежнему работают спасатели — им остается найти еще 16 человек. В общей сложности, найдены погибшими 64 человека, 13 остаются в больницах. «Газета.Ru» следила за ходом борьбы с последствиями возгорания в ТЦ Кемерово.nnВ Кемерово уже глубокая ночь – и «Газета.Ru» завершает онлайн-трансляцию. На месте трагедии продолжаются работы по разбору завалов – спасателям нужно найти еще 16 пропавших без вести при пожаре. За сегодняшний день число погибших возросло до 64 человек, 13 остаются в больницах, двое из них в тяжелом состоянии. Идет опознание тел погибших – сейчас опознаны 25 человек. По факту пожара ведется следствие: задержаны пятеро. В Кузбассе объявлен трехдневный траур по погибшим, три дня по жертвам трагедии будут скорбеть в Ингушетии в знак солидарности с Кузбассом. Днем скорби вторник, 27 марта, объявили также в Рязанской области и в Ингушетии. «Газета.Ru» продолжит следить за развитием событий.nnПравоохранители задержали сотрудника частного охранного предприятия, который отключил систему оповещения при пожаре в «Зимней вишне», передает ТАСС.nnСоболезнования президенту России Владимиру Путину выразила глава Эстонии Керсти Кальюлайд. «Я выражаю глубокие соболезнования семьям и близким жертв несчастного случая. В этот глубоко печальный момент все наши мысли с жителями России», — говорится в послании.nnВ Кемерово сейчас по местному времени — 01:30. Однако люди не покидают мемориал «Бульвар героев», который расположен недалеко от сгоревшего торгового центра. Территория заставлена горящими цветами, иконами, поминальными лампадами и мягкими игрушками.n25.03.2018nПубликация отnELENAn(@lena_feel_lena)n26 Мар 2018 в 10:49 PDTnnОпознаны 25 погибших, из них 13 детей. Самому младшему ребенку было пять лет, сообщает ТАСС.nnДетский лагерь «Артек» готов принять на реабилитацию детей, пострадавших из-за пожара в Кемерове. Об этом заявил директор центра Алексей Каспржак.nnn«Я созвонился с заместителем губернатора Кемеровской области Алексеем Зелениным и с начальником департамента молодежной политики и спорта Антоном Пятовским, и предложил детям, пострадавшим от пожара в торговом центре «Зимняя вишня», и детям из семей, где есть погибшие, приехать в «Артек» в ближайшее время, чтобы они могли психологически восстановиться после пережитого, снизить уровень напряжения и страха, облегчить боль от этой трагедии», — сообщил Каспржак ТАСС.nnНа месте трагедии продолжают работать спасатели: по-прежнему не найдены 16 человек. На данный момент известно о 64 погибших при пожаре. В больницах находятся 13 человек, двое из них в тяжелом состоянии. Из 64 погибших опознаны 23 человека.nnНа помощь семьям погибших и пострадавшим в ходе пожара в «Зимней вишне» российское правительство выделит 76 млн рублей.nnn«Из резервного фонда правительства России выделяются бюджетные ассигнования в размере 76 млн рублей на выплату единовременного пособия гражданам, пострадавшим в результате крупного пожара 25 марта 2018 года в Кемерово», — говорится на сайте кабинета министров РФ.nnnРанее премьер-министр России Дмитрий Медведев, что семьи жертв пожара получат по 1 млн рублей на одного погибшего. Пострадавшим выделат от 200 до 400 тыс. рублей в качестве единовременной выплаты.nnОперативному штабу, развернутому в кемеровской школе №7 на улице Пролетарской, требуется помощь добровольцев.nnn«Туда подгоняют фуры с едой, фуры с помощью. В школе работают только учителя, родственники либо плачут, либо просто сидят, очень мало людей. Нужны шесть-семь мужчин», – рассказал источник местного издания «VSE42.ru».nnВ числе глав государств, выразивших соболезнования президенту России Владимиру Путину, — ...
#
#
# Word2Vec recommendation:
# 2018-03-27 06:59:56,https://www.gazeta.ru/social/2018/03/27/11697127.shtml,-,Общество,Отдел «Общество»,По всей России созданы мемориалы памяти жертв пожара в Кемерово,"Россия скорбит по жертвам пожара в Кемерово: акции памяти прошли по всей стране, а в Кемерово состоялся стихийный митинг. В стране объявлен национальный траур. Следственный комитет продолжает расследование обстоятельств трагедии: пятерым фигурантам дела предъявлены обвинения. Поисково-спасательная операция завершена: на данный момент известно о 64 погибших. 28 марта в Кемерово похоронят тела 15 человек.nnВ Москве закончились акции на Манежной и Пушкинской площадях — люди разошлись и в окрестных магазинах закончились цветы. «Газета.Ru» завершает онлайн и обещает, что продолжит следить за развитием событий. Скорбим вместе со всей страной.nЧто произошло за деньnn— Спасатели завершили поисковую операцию в торговом центре «Зимняя вишня». Согласно последним данным, в результате пожара погибли 64 человек — среди них 41 ребенок.nnn— 28 марта состоятся похороны 15 опознанных погибших.nnn— Утром Владимир Путин прилетел в Кемерово, посетил пострадавших, провел совещание с главами ведомств, а также пообщался с инициативной группой горожан, которые высказали президенту недоверие к ходу расследования.nnn— На данный момент обвинения предъявлены пятерым задержанным подозреваемым.nnn— В Кемерове во вторник прошел стихийный митинг местных жителей — он продлился больше 10 часов. По разным оценкам, в нем приняли участие от 1,5 тыс. до 4 тыс. человек. Во время акции вице-губернатор Сергей Цивилев на коленях попросил прощения за пожар у собравшихся на городской площади.nnn— Траурные акции также прошли в Москве и Санкт-Петербурге. В столице прошло два мероприятия — на Манежной и Пушкинской площадях. В них приняли участие около 12 тыс. человек. В Санкт-Петербурге также прошли две акции в память о жертвах пожара в Кемерове: одна на Дворцовой площади, вторая — на Марсовом поле.nnДепутаты Рижской думы в Латвии почтили сегодня память погибших минутой молчания, сообщил мэр Риги Нил Ушаков в своем фейсбуке.nnn«С предложением о минуте молчания выступил депутат Юргис Клотиньш от «Национального объединения». В Риге сегодня скорбят все рижане», — написал он.nnnВ комментариях к посту — соболезнования от жителей Латвии и благодарности от россиян.nnГеография городов и регионов, где сегодня прошли акции в знак солидарности с жителями Кемерова, охватывает всю Россию.nnnПомимо регионов, о которых мы уже рассказали, люди несли цветы и мягкие игрушки к мемориалам в Башкирии, Удмуртии, Оренбуржье. В городах и станицах Краснодарского края в акциях приняли участие, в общей сложности, 50 тысяч человек, сообщает РИА «Новости».nnnА вот фото из станицы Новотитаровской Динского района Краснодарского края — там кто-то создал крохотный мемориал у Храма Андрея Первозванного.nКто-то сделал возле Храма Андрея Первозванного #кемеровомыстобойnПубликация отnНовотитаровская Newsn(@novotitarovskaya_news)n27 Мар 2018 в 11:01 PDTnnБелые воздушные шары летели сегодня в небо не только в Кемерово. Жители Краснодара также присоединились к акции.nАкция в память погибших в Кемерово! #Кемерово #Кемеровомыстобой #зимняявишняnПубликация отnФЕЙЕРВЕРКИ КРАСНОДАРn(@piro_krasnodar)n27 Мар 2018 в 11:34 PDTnnКак прошла в Москве акция на Пушкинской площади, можно посмотреть в фоторепортаже «Газеты.Ru» — наш корреспондент побывал на месте событий.nnВ двух траурных акциях в Москве — на Манежной и Пушкинской площадях — приняли участие около 12 тыс. человек. Об этом свидетельствуют данные ГУ МВД по столице.nnИсточник «Газеты.Ru» ранее уже заявлял о неисправности системы сигнализации в «Зимней вишне».nnn«Две недели назад уволился человек, который отвечал за пожарную сигнализацию. Сигнализация стала жить своей жизнью. Регулярно включалась. 23.03.18 ее отключили. Совсем. Вчера эта трагедия. Выезжали в ЧОП, которые охраняют ТЦ, изъяли журнал, где они сдавали-принимали смену. В журнале было написано, что пожарная сигнализация не работает», — сообщ ...
#
#
# FastText recommendation:
# 2018-03-27 06:59:56,https://www.gazeta.ru/social/2018/03/27/11697127.shtml,-,Общество,Отдел «Общество»,По всей России созданы мемориалы памяти жертв пожара в Кемерово,"Россия скорбит по жертвам пожара в Кемерово: акции памяти прошли по всей стране, а в Кемерово состоялся стихийный митинг. В стране объявлен национальный траур. Следственный комитет продолжает расследование обстоятельств трагедии: пятерым фигурантам дела предъявлены обвинения. Поисково-спасательная операция завершена: на данный момент известно о 64 погибших. 28 марта в Кемерово похоронят тела 15 человек.nnВ Москве закончились акции на Манежной и Пушкинской площадях — люди разошлись и в окрестных магазинах закончились цветы. «Газета.Ru» завершает онлайн и обещает, что продолжит следить за развитием событий. Скорбим вместе со всей страной.nЧто произошло за деньnn— Спасатели завершили поисковую операцию в торговом центре «Зимняя вишня». Согласно последним данным, в результате пожара погибли 64 человек — среди них 41 ребенок.nnn— 28 марта состоятся похороны 15 опознанных погибших.nnn— Утром Владимир Путин прилетел в Кемерово, посетил пострадавших, провел совещание с главами ведомств, а также пообщался с инициативной группой горожан, которые высказали президенту недоверие к ходу расследования.nnn— На данный момент обвинения предъявлены пятерым задержанным подозреваемым.nnn— В Кемерове во вторник прошел стихийный митинг местных жителей — он продлился больше 10 часов. По разным оценкам, в нем приняли участие от 1,5 тыс. до 4 тыс. человек. Во время акции вице-губернатор Сергей Цивилев на коленях попросил прощения за пожар у собравшихся на городской площади.nnn— Траурные акции также прошли в Москве и Санкт-Петербурге. В столице прошло два мероприятия — на Манежной и Пушкинской площадях. В них приняли участие около 12 тыс. человек. В Санкт-Петербурге также прошли две акции в память о жертвах пожара в Кемерове: одна на Дворцовой площади, вторая — на Марсовом поле.nnДепутаты Рижской думы в Латвии почтили сегодня память погибших минутой молчания, сообщил мэр Риги Нил Ушаков в своем фейсбуке.nnn«С предложением о минуте молчания выступил депутат Юргис Клотиньш от «Национального объединения». В Риге сегодня скорбят все рижане», — написал он.nnnВ комментариях к посту — соболезнования от жителей Латвии и благодарности от россиян.nnГеография городов и регионов, где сегодня прошли акции в знак солидарности с жителями Кемерова, охватывает всю Россию.nnnПомимо регионов, о которых мы уже рассказали, люди несли цветы и мягкие игрушки к мемориалам в Башкирии, Удмуртии, Оренбуржье. В городах и станицах Краснодарского края в акциях приняли участие, в общей сложности, 50 тысяч человек, сообщает РИА «Новости».nnnА вот фото из станицы Новотитаровской Динского района Краснодарского края — там кто-то создал крохотный мемориал у Храма Андрея Первозванного.nКто-то сделал возле Храма Андрея Первозванного #кемеровомыстобойnПубликация отnНовотитаровская Newsn(@novotitarovskaya_news)n27 Мар 2018 в 11:01 PDTnnБелые воздушные шары летели сегодня в небо не только в Кемерово. Жители Краснодара также присоединились к акции.nАкция в память погибших в Кемерово! #Кемерово #Кемеровомыстобой #зимняявишняnПубликация отnФЕЙЕРВЕРКИ КРАСНОДАРn(@piro_krasnodar)n27 Мар 2018 в 11:34 PDTnnКак прошла в Москве акция на Пушкинской площади, можно посмотреть в фоторепортаже «Газеты.Ru» — наш корреспондент побывал на месте событий.nnВ двух траурных акциях в Москве — на Манежной и Пушкинской площадях — приняли участие около 12 тыс. человек. Об этом свидетельствуют данные ГУ МВД по столице.nnИсточник «Газеты.Ru» ранее уже заявлял о неисправности системы сигнализации в «Зимней вишне».nnn«Две недели назад уволился человек, который отвечал за пожарную сигнализацию. Сигнализация стала жить своей жизнью. Регулярно включалась. 23.03.18 ее отключили. Совсем. Вчера эта трагедия. Выезжали в ЧОП, которые охраняют ТЦ, изъяли журнал, где они сдавали-принимали смену. В журнале было написано, что пожарная сигнализация не работает», — сообщ ...
#
#
# Word2Vec recommendation:
# 2018-02-11 15:48:05,https://www.gazeta.ru/social/2018/02/11/11645863.shtml,-,Общество,Отдел «Общество»,Пассажирский Ан-148 разбился после вылета из Домодедово,"После вылета из аэропорта Домодедово разбился самолет «Саратовских авиалиний» Ан-148, следовавший в Орск. На борту воскресного рейса находился 71 человек, включая 65 пассажиров и шесть членов экипажа. Все они погибли. В Оренбургской области объявлен траур. «Газета.Ru» следила за сообщениями с места катастрофы и оценивала возможные версии причин аварии в прямой трансляции.nnНа этом «Газета.Ru» завершает трансляцию. Редакция выражает свои соболезнования родственникам погибших. Будем продолжать следить за ходом расследования катастрофы. Оставайтесь с нами.nКоротко о катастрофе Ан-148nnСамолет «Саратовских авиалиний», следовавший по маршруту Москва-Орск, рухнул с высоты 2 километра через несколько минут после вылета из аэропорта Домодедово в воскресенье днем.nnnНа борту находилось 65 пассажиров и 6 членов экипажа — среди которых и два бортмеханика, готовивших самолет к вылету.nnnКатастрофа произошла практически мгновенно — по крайней мере пилоты не успели подать сигнал бедствия. Это может быть связанно либо с внезапным помпажом, а возможно взрывом двигателя в связи с технической неисправностью, либо с терактом. Рассматривается также версия потери управления самолетом в связи с обледенением — командир воздушного судна принял решение не проходить антиобледенительную обработку самолета перед вылетом.nnnНа месте крушения в Раменском районе Московской области продолжают работать сотни спасателей и следователей-криминалистов. Министр ЧС Владимир Пучков на ночном заседании штаба по ликвидации аварии рассказал, что обломки и фрагменты тел могут собирать до семи дней. Межгосударственный авиационный комитет обещает с рассветом задействовать беспилотники, с целью составления более полной картины произошедшего.nnnВ Оренбургской области сегодня объявлен траур. Соболезнования родственникам погибших выражают по всему миру — включая генсека ООН и руководство МОК.nnАгент хоккеиста-защитника владивостокского «Адмирала» Сергея Ильина в своем инстаграме рассказал, что в катастрофе погибла его невеста Дарья Толмасова. Ей было 22 года.nВ нашей семье случилось страшное горе...Сегодня в результате авиакатастрофы на борту самолёта следовавшего из Москвы в Орск погибла подруга нашего защитника «Адмирала» Сергея Ильина Дарья Толмасова...Ей было всего 22 года...Мы выражаем самые глубокие соболезнования нашему другу и его семье...Серёжа, держись и крепись ...nПубликация от @nshumi_agencynФев 11, 2018 в 7:27 PSTnnСоболезнования родственникам погибших поступают со всех концов мира. Наиболее заметным, среди прочих, являются слова генерального секретаря ООН. «Антониу Гутерриш с глубокой скорбью узнал о трагической авиакатастрофе в Московской области. Генеральный секретарь выражает искренние соболезнования семьям погибших, народу и правительству России», — цитирует слова официального представителя генсека Стефана Дюжаррика ТАСС.nnВ локальных пабликах Орска в соцсетях рассказывают, что родственники погибших и сочувствующие оставляют в аэропорту свечи и мягкие игрушки. В Оренбуржье объявлен траур.nnВ целом же выходит, что на 44 единицы построенных Ан-148 приходится 2 фатальных инцидента. И хотя выборка относительно невысокая, а нынешнюю аварию можно считать единственной за время регулярной коммерческой эксплуатации лайнера, показатель все равно крайне высокий. Например, число пассажирских самолетов другого класса, но примерно одинакового срока эксплуатации А-380, достигло 222 штук и при лишь двух значительных авариях, не повлекших потерь самолетов.nn«Газета.Ru» изучила отзывы на самолет от пассажиров на форумах гражданской авиации. Они как всегда противоречивые. Кому-то нравится компактность самолета при просторности салона (по сравнению с Боингами и Эйрбасами). Кто-то утверждает, что самолет может быть сильно неустойчив при смене эшелона, во время взлета и посадки возникает сильная турбулентность.nnКак расск ...
#
#
# FastText recommendation:
# 2018-02-11 15:48:05,https://www.gazeta.ru/social/2018/02/11/11645863.shtml,-,Общество,Отдел «Общество»,Пассажирский Ан-148 разбился после вылета из Домодедово,"После вылета из аэропорта Домодедово разбился самолет «Саратовских авиалиний» Ан-148, следовавший в Орск. На борту воскресного рейса находился 71 человек, включая 65 пассажиров и шесть членов экипажа. Все они погибли. В Оренбургской области объявлен траур. «Газета.Ru» следила за сообщениями с места катастрофы и оценивала возможные версии причин аварии в прямой трансляции.nnНа этом «Газета.Ru» завершает трансляцию. Редакция выражает свои соболезнования родственникам погибших. Будем продолжать следить за ходом расследования катастрофы. Оставайтесь с нами.nКоротко о катастрофе Ан-148nnСамолет «Саратовских авиалиний», следовавший по маршруту Москва-Орск, рухнул с высоты 2 километра через несколько минут после вылета из аэропорта Домодедово в воскресенье днем.nnnНа борту находилось 65 пассажиров и 6 членов экипажа — среди которых и два бортмеханика, готовивших самолет к вылету.nnnКатастрофа произошла практически мгновенно — по крайней мере пилоты не успели подать сигнал бедствия. Это может быть связанно либо с внезапным помпажом, а возможно взрывом двигателя в связи с технической неисправностью, либо с терактом. Рассматривается также версия потери управления самолетом в связи с обледенением — командир воздушного судна принял решение не проходить антиобледенительную обработку самолета перед вылетом.nnnНа месте крушения в Раменском районе Московской области продолжают работать сотни спасателей и следователей-криминалистов. Министр ЧС Владимир Пучков на ночном заседании штаба по ликвидации аварии рассказал, что обломки и фрагменты тел могут собирать до семи дней. Межгосударственный авиационный комитет обещает с рассветом задействовать беспилотники, с целью составления более полной картины произошедшего.nnnВ Оренбургской области сегодня объявлен траур. Соболезнования родственникам погибших выражают по всему миру — включая генсека ООН и руководство МОК.nnАгент хоккеиста-защитника владивостокского «Адмирала» Сергея Ильина в своем инстаграме рассказал, что в катастрофе погибла его невеста Дарья Толмасова. Ей было 22 года.nВ нашей семье случилось страшное горе...Сегодня в результате авиакатастрофы на борту самолёта следовавшего из Москвы в Орск погибла подруга нашего защитника «Адмирала» Сергея Ильина Дарья Толмасова...Ей было всего 22 года...Мы выражаем самые глубокие соболезнования нашему другу и его семье...Серёжа, держись и крепись ...nПубликация от @nshumi_agencynФев 11, 2018 в 7:27 PSTnnСоболезнования родственникам погибших поступают со всех концов мира. Наиболее заметным, среди прочих, являются слова генерального секретаря ООН. «Антониу Гутерриш с глубокой скорбью узнал о трагической авиакатастрофе в Московской области. Генеральный секретарь выражает искренние соболезнования семьям погибших, народу и правительству России», — цитирует слова официального представителя генсека Стефана Дюжаррика ТАСС.nnВ локальных пабликах Орска в соцсетях рассказывают, что родственники погибших и сочувствующие оставляют в аэропорту свечи и мягкие игрушки. В Оренбуржье объявлен траур.nnВ целом же выходит, что на 44 единицы построенных Ан-148 приходится 2 фатальных инцидента. И хотя выборка относительно невысокая, а нынешнюю аварию можно считать единственной за время регулярной коммерческой эксплуатации лайнера, показатель все равно крайне высокий. Например, число пассажирских самолетов другого класса, но примерно одинакового срока эксплуатации А-380, достигло 222 штук и при лишь двух значительных авариях, не повлекших потерь самолетов.nn«Газета.Ru» изучила отзывы на самолет от пассажиров на форумах гражданской авиации. Они как всегда противоречивые. Кому-то нравится компактность самолета при просторности салона (по сравнению с Боингами и Эйрбасами). Кто-то утверждает, что самолет может быть сильно неустойчив при смене эшелона, во время взлета и посадки возникает сильная турбулентность.nnКак расск ...
